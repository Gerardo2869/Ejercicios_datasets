# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
col_names = ['base_attack', 'base_stamina', 'base_defense']
# load dataset
pima = pd.read_csv("/content/drive/MyDrive/DataSets/Ejercicios/KNN guia/pokemon.csv", header=None, names=col_names)

# %%
pima.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                base_attack  \
# pokemon_id pokemon_name base_attack base_defense base_stamina type                rarity   charged_moves                                   fast_moves                  candy_required distance max_cp attack_probability base_capture_rate base_flee_rate dodge_probability max_pokemon_action_frequency min_pokemon_action_frequency found_egg found_evolution found_wild  found_research
# ...

# %%
# Select relevant feature columns
feature_cols = ['base_attack', 'base_defense', 'base_stamina']

# X will contain the feature columns
X = pokemon_data[feature_cols]

# y will be the target variable (let's use 'rarity' as an example)
y = pokemon_data['rarity']

# If you want to remove the first row for any reason, you can uncomment the following line
# X = X.iloc[1:]

# Display the first few rows of X and y to confirm
X.head(), y.head()
# Out:
# (   base_attack  base_defense  base_stamina
#  0          118           111           128
#  1          151           143           155
#  2          198           189           190
#  3          116            93           118
#  4          158           126           151,
#  0    Standard
#  1    Standard
#  2    Standard
#  3    Standard
#  4    Standard
#  Name: rarity, dtype: object)

# %%
y = y.iloc[1:]  # Esto elimina la primera fila

# %%
# Verifica si hay valores faltantes en X o y y los eliminamos de forma conjunta
X = X.dropna()
y = y.dropna()

# Aseguramos que X y y tengan el mismo número de filas
X, y = X.align(y, join='inner', axis=0)

# Aseguramos que la columna 'rarity' sea categórica
y = y.astype('category')

# Divide el dataset en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Verifica las dimensiones de los conjuntos para asegurarte de que la división fue correcta
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (704, 3) (302, 3) (704,) (302,)

# %%
y_train
# Out:
# 336    Standard
# 444    Standard
# 677    Standard
# 808      Mythic
# 811    Standard
#          ...
# 768    Standard
# 73     Standard
# 909    Standard
# 236    Standard
# 38     Standard
# Name: rarity, Length: 704, dtype: category
# Categories (4, object): ['Legendary', 'Mythic', 'Standard', 'Ultra beast']

# %%
# Crear el objeto del clasificador del árbol de decisión
clf = DecisionTreeClassifier()

# Entrenar el clasificador usando el conjunto de entrenamiento
clf = clf.fit(X_train, y_train)

# Predecir las respuestas para el conjunto de prueba
y_pred = clf.predict(X_test)

# Mostrar las primeras 5 predicciones como referencia
print("Predicciones:", y_pred[:5])
# Out:
# Predicciones: ['Standard' 'Standard' 'Standard' 'Standard' 'Standard']

# %%
y_pred
# Out:
# array(['Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Mythic', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Legendary', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Legendary',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Legendary',
#        'Standard', 'Standard', 'Standard', 'Standard', 'Standard',
# ...

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9072847682119205
